# %% [markdown]
# Aakanksha pisule B-23
#
# Practical No. 3

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

# %%
dataset = pd.read_csv('C://Users//Admin//Documents//ML_Practicals//datasent_names//Churn_Modelling.csv', index_col = 'RowNumber')
dataset.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2  \
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember
# RowNumber
# 1               0.00              1          1               1  \
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0

# %%
#Customer ID and Surname would not be relevant as features
X_columns = dataset.columns.tolist()[2:12]
Y_columns = dataset.columns.tolist()[-1:]
print(X_columns)
print(Y_columns)
# Out:
# ['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']
# ['Exited']

# %%
X = dataset[X_columns].values 
Y = dataset[Y_columns].values

# %%
#We need to encode categorical variables such as geography and gender
from sklearn.preprocessing import LabelEncoder
X_column_transformer = LabelEncoder()
X[:, 1] = X_column_transformer.fit_transform(X[:, 1])

# %%
#Lets Encode gender now
X[:, 2] = X_column_transformer.fit_transform(X[:, 2])

# %% [markdown]
# We are treating countries with ordinal values(0 < 1 < 2) but they are incomparable. To solve this we can use one hot encoding. We will perform some standardization

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

pipeline = Pipeline(
    [
        ('Categorizer', ColumnTransformer(
            [
                ("Gender Label Encoder", OneHotEncoder(categories = 'auto', drop = 'first'), [2]),
                ("Geography Label Encoder", OneHotEncoder(categories = 'auto', drop = 'first'), [1])
            ], 
            remainder = 'passthrough', n_jobs = 1)),
        ('Normalizer', StandardScaler())
    ]
)

# %%
#Standardize the features
X = pipeline.fit_transform(X)

# %%
#Spilt the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
#Let us create the Neural Network
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
#Initialize ANN
classifier = Sequential()

# %%
#Add input layer and hidden layer
classifier.add(Dense(6, activation = 'relu', input_shape = (X_train.shape[1], )))
classifier.add(Dropout(rate = 0.1))

# %%
#Add second layer
classifier.add(Dense(6, activation = 'relu'))
classifier.add(Dropout(rate = 0.1))

# %%
#Add output layer
classifier.add(Dense(1, activation = 'sigmoid'))

# %%
#Let us take a look at our network
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 72
#
#  dropout (Dropout)           (None, 6)                 0
#
#  dense_1 (Dense)             (None, 6)                 42
#
#  dropout_1 (Dropout)         (None, 6)                 0
#
#  dense_2 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 121 (484.00 Byte)
# Trainable params: 121 (484.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Optimize the weights
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
#Fitting the Neural Network
history = classifier.fit(X_train, y_train, batch_size = 32, epochs = 200, validation_split = 0.1, verbose = 2)
# Out:
# Epoch 1/200
# 225/225 - 6s - loss: 0.6418 - accuracy: 0.6840 - val_loss: 0.5163 - val_accuracy: 0.7950 - 6s/epoch - 25ms/step
# Epoch 2/200
# 225/225 - 1s - loss: 0.5114 - accuracy: 0.7921 - val_loss: 0.4852 - val_accuracy: 0.7950 - 740ms/epoch - 3ms/step
# Epoch 3/200
# 225/225 - 1s - loss: 0.4900 - accuracy: 0.7929 - val_loss: 0.4666 - val_accuracy: 0.7950 - 717ms/epoch - 3ms/step
# Epoch 4/200
# 225/225 - 1s - loss: 0.4780 - accuracy: 0.7953 - val_loss: 0.4529 - val_accuracy: 0.7950 - 723ms/epoch - 3ms/step
# Epoch 5/200
# 225/225 - 1s - loss: 0.4657 - accuracy: 0.7953 - val_loss: 0.4423 - val_accuracy: 0.7950 - 676ms/epoch - 3ms/step
# Epoch 6/200
# 225/225 - 1s - loss: 0.4592 - accuracy: 0.7936 - val_loss: 0.4352 - val_accuracy: 0.7950 - 717ms/epoch - 3ms/step
# Epoch 7/200
# 225/225 - 1s - loss: 0.4548 - accuracy: 0.7949 - val_loss: 0.4270 - val_accuracy: 0.7950 - 635ms/epoch - 3ms/step
# Epoch 8/200
# 225/225 - 1s - loss: 0.4454 - accuracy: 0.7958 - val_loss: 0.4177 - val_accuracy: 0.7950 - 1s/epoch - 5ms/step
# Epoch 9/200
# 225/225 - 1s - loss: 0.4380 - accuracy: 0.7972 - val_loss: 0.4084 - val_accuracy: 0.7962 - 883ms/epoch - 4ms/step
# Epoch 10/200
# 225/225 - 1s - loss: 0.4339 - accuracy: 0.7997 - val_loss: 0.4035 - val_accuracy: 0.7987 - 695ms/epoch - 3ms/step
# Epoch 11/200
# 225/225 - 1s - loss: 0.4311 - accuracy: 0.8050 - val_loss: 0.3973 - val_accuracy: 0.8050 - 705ms/epoch - 3ms/step
# Epoch 12/200
# 225/225 - 1s - loss: 0.4308 - accuracy: 0.8083 - val_loss: 0.3929 - val_accuracy: 0.8225 - 794ms/epoch - 4ms/step
# Epoch 13/200
# 225/225 - 1s - loss: 0.4212 - accuracy: 0.8153 - val_loss: 0.3901 - val_accuracy: 0.8225 - 951ms/epoch - 4ms/step
# Epoch 14/200
# 225/225 - 1s - loss: 0.4221 - accuracy: 0.8146 - val_loss: 0.3852 - val_accuracy: 0.8288 - 774ms/epoch - 3ms/step
# Epoch 15/200
# 225/225 - 1s - loss: 0.4215 - accuracy: 0.8149 - val_loss: 0.3797 - val_accuracy: 0.8338 - 665ms/epoch - 3ms/step
# Epoch 16/200
# 225/225 - 1s - loss: 0.4157 - accuracy: 0.8192 - val_loss: 0.3765 - val_accuracy: 0.8338 - 683ms/epoch - 3ms/step
# Epoch 17/200
# 225/225 - 1s - loss: 0.4180 - accuracy: 0.8160 - val_loss: 0.3740 - val_accuracy: 0.8313 - 664ms/epoch - 3ms/step
# Epoch 18/200
# 225/225 - 1s - loss: 0.4123 - accuracy: 0.8165 - val_loss: 0.3705 - val_accuracy: 0.8313 - 945ms/epoch - 4ms/step
# Epoch 19/200
# 225/225 - 1s - loss: 0.4149 - accuracy: 0.8144 - val_loss: 0.3683 - val_accuracy: 0.8325 - 640ms/epoch - 3ms/step
# Epoch 20/200
# 225/225 - 1s - loss: 0.4079 - accuracy: 0.8154 - val_loss: 0.3693 - val_accuracy: 0.8325 - 667ms/epoch - 3ms/step
# Epoch 21/200
# 225/225 - 1s - loss: 0.4070 - accuracy: 0.8194 - val_loss: 0.3671 - val_accuracy: 0.8300 - 699ms/epoch - 3ms/step
# Epoch 22/200
# 225/225 - 1s - loss: 0.4121 - accuracy: 0.8168 - val_loss: 0.3651 - val_accuracy: 0.8325 - 853ms/epoch - 4ms/step
# Epoch 23/200
# 225/225 - 1s - loss: 0.4050 - accuracy: 0.8207 - val_loss: 0.3650 - val_accuracy: 0.8350 - 885ms/epoch - 4ms/step
# Epoch 24/200
# 225/225 - 1s - loss: 0.4026 - accuracy: 0.8206 - val_loss: 0.3617 - val_accuracy: 0.8375 - 1s/epoch - 5ms/step
# Epoch 25/200
# 225/225 - 1s - loss: 0.4049 - accuracy: 0.8226 - val_loss: 0.3613 - val_accuracy: 0.8375 - 914ms/epoch - 4ms/step
# Epoch 26/200
# 225/225 - 1s - loss: 0.4031 - accuracy: 0.8211 - val_loss: 0.3605 - val_accuracy: 0.8375 - 1s/epoch - 6ms/step
# Epoch 27/200
# 225/225 - 1s - loss: 0.4022 - accuracy: 0.8197 - val_loss: 0.3587 - val_accuracy: 0.8375 - 654ms/epoch - 3ms/step
# Epoch 28/200
# 225/225 - 1s - loss: 0.4007 - accuracy: 0.8188 - val_loss: 0.3567 - val_accuracy: 0.8413 - 1s/epoch - 6ms/step
# Epoch 29/200
# 225/225 - 1s - loss: 0.4042 - accuracy: 0.8188 - val_loss: 0.3583 - val_accuracy: 0.8425 - 662ms/epoch - 3ms/step
# Epoch 30/200
# 225/225 - 1s - loss: 0.4016 - accuracy: 0.8206 - val_loss: 0.3587 - val_accuracy: 0.8487 - 681ms/epoch - 3ms/step
# Epoch 31/200
# 225/225 - 1s - loss: 0.3972 - accuracy: 0.8228 - val_loss: 0.3591 - val_accuracy: 0.8487 - 662ms/epoch - 3ms/step
# Epoch 32/200
# 225/225 - 1s - loss: 0.4002 - accuracy: 0.8225 - val_loss: 0.3581 - val_accuracy: 0.8475 - 728ms/epoch - 3ms/step
# Epoch 33/200
# 225/225 - 1s - loss: 0.3966 - accuracy: 0.8231 - val_loss: 0.3545 - val_accuracy: 0.8462 - 793ms/epoch - 4ms/step
# Epoch 34/200
# 225/225 - 1s - loss: 0.4028 - accuracy: 0.8222 - val_loss: 0.3576 - val_accuracy: 0.8487 - 699ms/epoch - 3ms/step
# Epoch 35/200
# 225/225 - 1s - loss: 0.3984 - accuracy: 0.8192 - val_loss: 0.3573 - val_accuracy: 0.8462 - 659ms/epoch - 3ms/step
# Epoch 36/200
# 225/225 - 1s - loss: 0.4020 - accuracy: 0.8207 - val_loss: 0.3568 - val_accuracy: 0.8475 - 733ms/epoch - 3ms/step
# Epoch 37/200
# 225/225 - 1s - loss: 0.3936 - accuracy: 0.8247 - val_loss: 0.3549 - val_accuracy: 0.8500 - 755ms/epoch - 3ms/step
# Epoch 38/200
# 225/225 - 1s - loss: 0.3954 - accuracy: 0.8235 - val_loss: 0.3575 - val_accuracy: 0.8475 - 646ms/epoch - 3ms/step
# Epoch 39/200
# 225/225 - 1s - loss: 0.4012 - accuracy: 0.8192 - val_loss: 0.3531 - val_accuracy: 0.8487 - 633ms/epoch - 3ms/step
# Epoch 40/200
# 225/225 - 1s - loss: 0.3971 - accuracy: 0.8233 - val_loss: 0.3559 - val_accuracy: 0.8500 - 780ms/epoch - 3ms/step
# Epoch 41/200
# 225/225 - 1s - loss: 0.3954 - accuracy: 0.8225 - val_loss: 0.3538 - val_accuracy: 0.8525 - 1s/epoch - 7ms/step
# Epoch 42/200
# 225/225 - 1s - loss: 0.3917 - accuracy: 0.8257 - val_loss: 0.3556 - val_accuracy: 0.8487 - 1s/epoch - 5ms/step
# Epoch 43/200
# 225/225 - 1s - loss: 0.3955 - accuracy: 0.8228 - val_loss: 0.3538 - val_accuracy: 0.8537 - 630ms/epoch - 3ms/step
# Epoch 44/200
# 225/225 - 1s - loss: 0.3978 - accuracy: 0.8207 - val_loss: 0.3536 - val_accuracy: 0.8487 - 794ms/epoch - 4ms/step
# Epoch 45/200
# 225/225 - 1s - loss: 0.3989 - accuracy: 0.8197 - val_loss: 0.3549 - val_accuracy: 0.8537 - 645ms/epoch - 3ms/step
# Epoch 46/200
# 225/225 - 1s - loss: 0.3922 - accuracy: 0.8240 - val_loss: 0.3536 - val_accuracy: 0.8537 - 622ms/epoch - 3ms/step
# Epoch 47/200
# 225/225 - 1s - loss: 0.3954 - accuracy: 0.8233 - val_loss: 0.3541 - val_accuracy: 0.8525 - 637ms/epoch - 3ms/step
# Epoch 48/200
# 225/225 - 1s - loss: 0.4006 - accuracy: 0.8199 - val_loss: 0.3528 - val_accuracy: 0.8562 - 633ms/epoch - 3ms/step
# Epoch 49/200
# 225/225 - 1s - loss: 0.3975 - accuracy: 0.8210 - val_loss: 0.3534 - val_accuracy: 0.8575 - 637ms/epoch - 3ms/step
# Epoch 50/200
# 225/225 - 1s - loss: 0.3914 - accuracy: 0.8253 - val_loss: 0.3516 - val_accuracy: 0.8537 - 656ms/epoch - 3ms/step
# Epoch 51/200
# 225/225 - 1s - loss: 0.3978 - accuracy: 0.8197 - val_loss: 0.3528 - val_accuracy: 0.8537 - 841ms/epoch - 4ms/step
# Epoch 52/200
# 225/225 - 1s - loss: 0.3922 - accuracy: 0.8261 - val_loss: 0.3521 - val_accuracy: 0.8550 - 641ms/epoch - 3ms/step
# Epoch 53/200
# 225/225 - 1s - loss: 0.3926 - accuracy: 0.8226 - val_loss: 0.3515 - val_accuracy: 0.8575 - 677ms/epoch - 3ms/step
# Epoch 54/200
# 225/225 - 1s - loss: 0.3945 - accuracy: 0.8218 - val_loss: 0.3515 - val_accuracy: 0.8562 - 661ms/epoch - 3ms/step
# Epoch 55/200
# 225/225 - 1s - loss: 0.3925 - accuracy: 0.8203 - val_loss: 0.3516 - val_accuracy: 0.8587 - 643ms/epoch - 3ms/step
# Epoch 56/200
# 225/225 - 1s - loss: 0.3910 - accuracy: 0.8263 - val_loss: 0.3503 - val_accuracy: 0.8575 - 648ms/epoch - 3ms/step
# Epoch 57/200
# 225/225 - 1s - loss: 0.3889 - accuracy: 0.8229 - val_loss: 0.3485 - val_accuracy: 0.8612 - 646ms/epoch - 3ms/step
# Epoch 58/200
# 225/225 - 1s - loss: 0.3848 - accuracy: 0.8235 - val_loss: 0.3472 - val_accuracy: 0.8600 - 834ms/epoch - 4ms/step
# Epoch 59/200
# 225/225 - 1s - loss: 0.3935 - accuracy: 0.8194 - val_loss: 0.3501 - val_accuracy: 0.8587 - 777ms/epoch - 3ms/step
# Epoch 60/200
# 225/225 - 1s - loss: 0.3925 - accuracy: 0.8183 - val_loss: 0.3501 - val_accuracy: 0.8575 - 642ms/epoch - 3ms/step
# Epoch 61/200
# 225/225 - 1s - loss: 0.3911 - accuracy: 0.8201 - val_loss: 0.3528 - val_accuracy: 0.8550 - 705ms/epoch - 3ms/step
# Epoch 62/200
# 225/225 - 1s - loss: 0.3907 - accuracy: 0.8217 - val_loss: 0.3501 - val_accuracy: 0.8587 - 802ms/epoch - 4ms/step
# Epoch 63/200
# 225/225 - 1s - loss: 0.3918 - accuracy: 0.8324 - val_loss: 0.3482 - val_accuracy: 0.8675 - 1s/epoch - 6ms/step
# Epoch 64/200
# 225/225 - 1s - loss: 0.3863 - accuracy: 0.8408 - val_loss: 0.3468 - val_accuracy: 0.8675 - 1s/epoch - 5ms/step
# Epoch 65/200
# 225/225 - 1s - loss: 0.3915 - accuracy: 0.8369 - val_loss: 0.3502 - val_accuracy: 0.8675 - 863ms/epoch - 4ms/step
# Epoch 66/200
# 225/225 - 1s - loss: 0.3868 - accuracy: 0.8432 - val_loss: 0.3485 - val_accuracy: 0.8675 - 779ms/epoch - 3ms/step
# Epoch 67/200
# 225/225 - 1s - loss: 0.3903 - accuracy: 0.8386 - val_loss: 0.3470 - val_accuracy: 0.8712 - 762ms/epoch - 3ms/step
# Epoch 68/200
# 225/225 - 1s - loss: 0.3917 - accuracy: 0.8382 - val_loss: 0.3490 - val_accuracy: 0.8687 - 742ms/epoch - 3ms/step
# Epoch 69/200
# 225/225 - 1s - loss: 0.3845 - accuracy: 0.8407 - val_loss: 0.3458 - val_accuracy: 0.8675 - 637ms/epoch - 3ms/step
# Epoch 70/200
# 225/225 - 1s - loss: 0.3846 - accuracy: 0.8421 - val_loss: 0.3452 - val_accuracy: 0.8650 - 642ms/epoch - 3ms/step
# Epoch 71/200
# 225/225 - 1s - loss: 0.3899 - accuracy: 0.8410 - val_loss: 0.3468 - val_accuracy: 0.8725 - 637ms/epoch - 3ms/step
# Epoch 72/200
# 225/225 - 1s - loss: 0.3910 - accuracy: 0.8385 - val_loss: 0.3477 - val_accuracy: 0.8700 - 631ms/epoch - 3ms/step
# Epoch 73/200
# 225/225 - 1s - loss: 0.3849 - accuracy: 0.8426 - val_loss: 0.3460 - val_accuracy: 0.8687 - 637ms/epoch - 3ms/step
# Epoch 74/200
# 225/225 - 1s - loss: 0.3873 - accuracy: 0.8432 - val_loss: 0.3463 - val_accuracy: 0.8737 - 632ms/epoch - 3ms/step
# Epoch 75/200
# 225/225 - 1s - loss: 0.3802 - accuracy: 0.8433 - val_loss: 0.3481 - val_accuracy: 0.8675 - 641ms/epoch - 3ms/step
# Epoch 76/200
# 225/225 - 1s - loss: 0.3803 - accuracy: 0.8447 - val_loss: 0.3449 - val_accuracy: 0.8712 - 632ms/epoch - 3ms/step
# Epoch 77/200
# 225/225 - 1s - loss: 0.3851 - accuracy: 0.8408 - val_loss: 0.3460 - val_accuracy: 0.8737 - 634ms/epoch - 3ms/step
# Epoch 78/200
# 225/225 - 1s - loss: 0.3835 - accuracy: 0.8439 - val_loss: 0.3454 - val_accuracy: 0.8737 - 772ms/epoch - 3ms/step
# Epoch 79/200
# 225/225 - 1s - loss: 0.3894 - accuracy: 0.8424 - val_loss: 0.3472 - val_accuracy: 0.8700 - 626ms/epoch - 3ms/step
# Epoch 80/200
# 225/225 - 1s - loss: 0.3907 - accuracy: 0.8433 - val_loss: 0.3482 - val_accuracy: 0.8675 - 936ms/epoch - 4ms/step
# Epoch 81/200
# 225/225 - 1s - loss: 0.3859 - accuracy: 0.8436 - val_loss: 0.3460 - val_accuracy: 0.8700 - 669ms/epoch - 3ms/step
# Epoch 82/200
# 225/225 - 1s - loss: 0.3833 - accuracy: 0.8447 - val_loss: 0.3457 - val_accuracy: 0.8700 - 759ms/epoch - 3ms/step
# Epoch 83/200
# 225/225 - 1s - loss: 0.3825 - accuracy: 0.8432 - val_loss: 0.3469 - val_accuracy: 0.8675 - 640ms/epoch - 3ms/step
# Epoch 84/200
# 225/225 - 1s - loss: 0.3856 - accuracy: 0.8433 - val_loss: 0.3464 - val_accuracy: 0.8637 - 655ms/epoch - 3ms/step
# Epoch 85/200
# 225/225 - 1s - loss: 0.3837 - accuracy: 0.8454 - val_loss: 0.3443 - val_accuracy: 0.8675 - 642ms/epoch - 3ms/step
# Epoch 86/200
# 225/225 - 1s - loss: 0.3793 - accuracy: 0.8438 - val_loss: 0.3433 - val_accuracy: 0.8662 - 661ms/epoch - 3ms/step
# Epoch 87/200
# 225/225 - 1s - loss: 0.3855 - accuracy: 0.8399 - val_loss: 0.3419 - val_accuracy: 0.8675 - 931ms/epoch - 4ms/step
# Epoch 88/200
# 225/225 - 1s - loss: 0.3810 - accuracy: 0.8438 - val_loss: 0.3450 - val_accuracy: 0.8662 - 765ms/epoch - 3ms/step
# Epoch 89/200
# 225/225 - 1s - loss: 0.3846 - accuracy: 0.8436 - val_loss: 0.3433 - val_accuracy: 0.8700 - 787ms/epoch - 3ms/step
# Epoch 90/200
# 225/225 - 1s - loss: 0.3828 - accuracy: 0.8436 - val_loss: 0.3424 - val_accuracy: 0.8712 - 680ms/epoch - 3ms/step
# Epoch 91/200
# 225/225 - 1s - loss: 0.3820 - accuracy: 0.8462 - val_loss: 0.3420 - val_accuracy: 0.8700 - 767ms/epoch - 3ms/step
# Epoch 92/200
# 225/225 - 1s - loss: 0.3854 - accuracy: 0.8397 - val_loss: 0.3442 - val_accuracy: 0.8687 - 818ms/epoch - 4ms/step
# Epoch 93/200
# 225/225 - 1s - loss: 0.3819 - accuracy: 0.8449 - val_loss: 0.3417 - val_accuracy: 0.8700 - 636ms/epoch - 3ms/step
# Epoch 94/200
# 225/225 - 1s - loss: 0.3788 - accuracy: 0.8450 - val_loss: 0.3417 - val_accuracy: 0.8763 - 776ms/epoch - 3ms/step
# Epoch 95/200
# 225/225 - 1s - loss: 0.3780 - accuracy: 0.8485 - val_loss: 0.3408 - val_accuracy: 0.8737 - 754ms/epoch - 3ms/step
# Epoch 96/200
# 225/225 - 1s - loss: 0.3808 - accuracy: 0.8465 - val_loss: 0.3443 - val_accuracy: 0.8587 - 745ms/epoch - 3ms/step
# Epoch 97/200
# 225/225 - 1s - loss: 0.3790 - accuracy: 0.8461 - val_loss: 0.3415 - val_accuracy: 0.8725 - 693ms/epoch - 3ms/step
# Epoch 98/200
# 225/225 - 1s - loss: 0.3778 - accuracy: 0.8471 - val_loss: 0.3414 - val_accuracy: 0.8712 - 757ms/epoch - 3ms/step
# Epoch 99/200
# 225/225 - 1s - loss: 0.3794 - accuracy: 0.8461 - val_loss: 0.3404 - val_accuracy: 0.8725 - 756ms/epoch - 3ms/step
# Epoch 100/200
# 225/225 - 1s - loss: 0.3741 - accuracy: 0.8478 - val_loss: 0.3388 - val_accuracy: 0.8725 - 751ms/epoch - 3ms/step
# Epoch 101/200
# 225/225 - 1s - loss: 0.3775 - accuracy: 0.8483 - val_loss: 0.3424 - val_accuracy: 0.8662 - 771ms/epoch - 3ms/step
# Epoch 102/200
# 225/225 - 1s - loss: 0.3753 - accuracy: 0.8501 - val_loss: 0.3401 - val_accuracy: 0.8712 - 765ms/epoch - 3ms/step
# Epoch 103/200
# 225/225 - 1s - loss: 0.3750 - accuracy: 0.8474 - val_loss: 0.3416 - val_accuracy: 0.8737 - 747ms/epoch - 3ms/step
# Epoch 104/200
# 225/225 - 1s - loss: 0.3795 - accuracy: 0.8456 - val_loss: 0.3392 - val_accuracy: 0.8712 - 774ms/epoch - 3ms/step
# Epoch 105/200
# 225/225 - 1s - loss: 0.3788 - accuracy: 0.8462 - val_loss: 0.3445 - val_accuracy: 0.8637 - 969ms/epoch - 4ms/step
# Epoch 106/200
# 225/225 - 1s - loss: 0.3724 - accuracy: 0.8506 - val_loss: 0.3393 - val_accuracy: 0.8675 - 851ms/epoch - 4ms/step
# Epoch 107/200
# 225/225 - 1s - loss: 0.3848 - accuracy: 0.8446 - val_loss: 0.3407 - val_accuracy: 0.8650 - 1s/epoch - 4ms/step
# Epoch 108/200
# 225/225 - 1s - loss: 0.3805 - accuracy: 0.8465 - val_loss: 0.3401 - val_accuracy: 0.8675 - 729ms/epoch - 3ms/step
# Epoch 109/200
# 225/225 - 1s - loss: 0.3754 - accuracy: 0.8426 - val_loss: 0.3379 - val_accuracy: 0.8712 - 760ms/epoch - 3ms/step
# Epoch 110/200
# 225/225 - 1s - loss: 0.3774 - accuracy: 0.8460 - val_loss: 0.3382 - val_accuracy: 0.8712 - 693ms/epoch - 3ms/step
# Epoch 111/200
# 225/225 - 1s - loss: 0.3802 - accuracy: 0.8457 - val_loss: 0.3427 - val_accuracy: 0.8625 - 795ms/epoch - 4ms/step
# Epoch 112/200
# 225/225 - 1s - loss: 0.3765 - accuracy: 0.8475 - val_loss: 0.3386 - val_accuracy: 0.8687 - 663ms/epoch - 3ms/step
# Epoch 113/200
# 225/225 - 1s - loss: 0.3748 - accuracy: 0.8489 - val_loss: 0.3411 - val_accuracy: 0.8625 - 730ms/epoch - 3ms/step
# Epoch 114/200
# 225/225 - 1s - loss: 0.3806 - accuracy: 0.8453 - val_loss: 0.3399 - val_accuracy: 0.8687 - 615ms/epoch - 3ms/step
# Epoch 115/200
# 225/225 - 1s - loss: 0.3805 - accuracy: 0.8471 - val_loss: 0.3380 - val_accuracy: 0.8700 - 666ms/epoch - 3ms/step
# Epoch 116/200
# 225/225 - 1s - loss: 0.3786 - accuracy: 0.8478 - val_loss: 0.3390 - val_accuracy: 0.8687 - 778ms/epoch - 3ms/step
# Epoch 117/200
# 225/225 - 1s - loss: 0.3773 - accuracy: 0.8465 - val_loss: 0.3397 - val_accuracy: 0.8650 - 753ms/epoch - 3ms/step
# Epoch 118/200
# 225/225 - 1s - loss: 0.3818 - accuracy: 0.8438 - val_loss: 0.3377 - val_accuracy: 0.8700 - 646ms/epoch - 3ms/step
# Epoch 119/200
# 225/225 - 1s - loss: 0.3791 - accuracy: 0.8474 - val_loss: 0.3381 - val_accuracy: 0.8662 - 635ms/epoch - 3ms/step
# Epoch 120/200
# 225/225 - 1s - loss: 0.3762 - accuracy: 0.8461 - val_loss: 0.3382 - val_accuracy: 0.8687 - 647ms/epoch - 3ms/step
# Epoch 121/200
# 225/225 - 1s - loss: 0.3811 - accuracy: 0.8454 - val_loss: 0.3350 - val_accuracy: 0.8700 - 693ms/epoch - 3ms/step
# Epoch 122/200
# 225/225 - 1s - loss: 0.3795 - accuracy: 0.8457 - val_loss: 0.3375 - val_accuracy: 0.8650 - 865ms/epoch - 4ms/step
# Epoch 123/200
# 225/225 - 1s - loss: 0.3791 - accuracy: 0.8447 - val_loss: 0.3369 - val_accuracy: 0.8662 - 711ms/epoch - 3ms/step
# Epoch 124/200
# 225/225 - 1s - loss: 0.3793 - accuracy: 0.8447 - val_loss: 0.3369 - val_accuracy: 0.8675 - 672ms/epoch - 3ms/step
# Epoch 125/200
# 225/225 - 1s - loss: 0.3802 - accuracy: 0.8460 - val_loss: 0.3371 - val_accuracy: 0.8587 - 1s/epoch - 5ms/step
# Epoch 126/200
# 225/225 - 1s - loss: 0.3742 - accuracy: 0.8478 - val_loss: 0.3387 - val_accuracy: 0.8575 - 680ms/epoch - 3ms/step
# Epoch 127/200
# 225/225 - 1s - loss: 0.3762 - accuracy: 0.8483 - val_loss: 0.3377 - val_accuracy: 0.8612 - 781ms/epoch - 3ms/step
# Epoch 128/200
# 225/225 - 1s - loss: 0.3791 - accuracy: 0.8456 - val_loss: 0.3382 - val_accuracy: 0.8612 - 626ms/epoch - 3ms/step
# Epoch 129/200
# 225/225 - 1s - loss: 0.3730 - accuracy: 0.8536 - val_loss: 0.3360 - val_accuracy: 0.8650 - 660ms/epoch - 3ms/step
# Epoch 130/200
# 225/225 - 1s - loss: 0.3788 - accuracy: 0.8472 - val_loss: 0.3382 - val_accuracy: 0.8612 - 707ms/epoch - 3ms/step
# Epoch 131/200
# 225/225 - 1s - loss: 0.3780 - accuracy: 0.8469 - val_loss: 0.3374 - val_accuracy: 0.8625 - 736ms/epoch - 3ms/step
# Epoch 132/200
# 225/225 - 1s - loss: 0.3726 - accuracy: 0.8492 - val_loss: 0.3367 - val_accuracy: 0.8637 - 712ms/epoch - 3ms/step
# Epoch 133/200
# 225/225 - 1s - loss: 0.3734 - accuracy: 0.8497 - val_loss: 0.3341 - val_accuracy: 0.8687 - 787ms/epoch - 3ms/step
# Epoch 134/200
# 225/225 - 1s - loss: 0.3745 - accuracy: 0.8471 - val_loss: 0.3345 - val_accuracy: 0.8675 - 884ms/epoch - 4ms/step
# Epoch 135/200
# 225/225 - 1s - loss: 0.3733 - accuracy: 0.8501 - val_loss: 0.3340 - val_accuracy: 0.8700 - 718ms/epoch - 3ms/step
# Epoch 136/200
# 225/225 - 1s - loss: 0.3702 - accuracy: 0.8494 - val_loss: 0.3344 - val_accuracy: 0.8637 - 1s/epoch - 5ms/step
# Epoch 137/200
# 225/225 - 1s - loss: 0.3720 - accuracy: 0.8515 - val_loss: 0.3371 - val_accuracy: 0.8587 - 1s/epoch - 5ms/step
# Epoch 138/200
# 225/225 - 1s - loss: 0.3744 - accuracy: 0.8472 - val_loss: 0.3384 - val_accuracy: 0.8587 - 1s/epoch - 5ms/step
# Epoch 139/200
# 225/225 - 1s - loss: 0.3755 - accuracy: 0.8501 - val_loss: 0.3363 - val_accuracy: 0.8587 - 746ms/epoch - 3ms/step
# Epoch 140/200
# 225/225 - 1s - loss: 0.3756 - accuracy: 0.8475 - val_loss: 0.3349 - val_accuracy: 0.8650 - 1s/epoch - 5ms/step
# Epoch 141/200
# 225/225 - 1s - loss: 0.3707 - accuracy: 0.8503 - val_loss: 0.3337 - val_accuracy: 0.8600 - 884ms/epoch - 4ms/step
# Epoch 142/200
# 225/225 - 1s - loss: 0.3786 - accuracy: 0.8462 - val_loss: 0.3361 - val_accuracy: 0.8562 - 679ms/epoch - 3ms/step
# Epoch 143/200
# 225/225 - 1s - loss: 0.3773 - accuracy: 0.8501 - val_loss: 0.3382 - val_accuracy: 0.8612 - 834ms/epoch - 4ms/step
# Epoch 144/200
# 225/225 - 1s - loss: 0.3749 - accuracy: 0.8467 - val_loss: 0.3355 - val_accuracy: 0.8625 - 644ms/epoch - 3ms/step
# Epoch 145/200
# 225/225 - 1s - loss: 0.3761 - accuracy: 0.8476 - val_loss: 0.3369 - val_accuracy: 0.8600 - 631ms/epoch - 3ms/step
# Epoch 146/200
# 225/225 - 1s - loss: 0.3774 - accuracy: 0.8483 - val_loss: 0.3404 - val_accuracy: 0.8600 - 774ms/epoch - 3ms/step
# Epoch 147/200
# 225/225 - 1s - loss: 0.3730 - accuracy: 0.8510 - val_loss: 0.3354 - val_accuracy: 0.8662 - 671ms/epoch - 3ms/step
# Epoch 148/200
# 225/225 - 1s - loss: 0.3787 - accuracy: 0.8468 - val_loss: 0.3357 - val_accuracy: 0.8650 - 826ms/epoch - 4ms/step
# Epoch 149/200
# 225/225 - 1s - loss: 0.3714 - accuracy: 0.8507 - val_loss: 0.3368 - val_accuracy: 0.8550 - 823ms/epoch - 4ms/step
# Epoch 150/200
# 225/225 - 1s - loss: 0.3745 - accuracy: 0.8501 - val_loss: 0.3342 - val_accuracy: 0.8612 - 825ms/epoch - 4ms/step
# Epoch 151/200
# 225/225 - 1s - loss: 0.3769 - accuracy: 0.8490 - val_loss: 0.3357 - val_accuracy: 0.8625 - 689ms/epoch - 3ms/step
# Epoch 152/200
# 225/225 - 1s - loss: 0.3743 - accuracy: 0.8515 - val_loss: 0.3350 - val_accuracy: 0.8587 - 1s/epoch - 5ms/step
# Epoch 153/200
# 225/225 - 1s - loss: 0.3729 - accuracy: 0.8499 - val_loss: 0.3325 - val_accuracy: 0.8662 - 660ms/epoch - 3ms/step
# Epoch 154/200
# 225/225 - 1s - loss: 0.3719 - accuracy: 0.8514 - val_loss: 0.3318 - val_accuracy: 0.8712 - 944ms/epoch - 4ms/step
# Epoch 155/200
# 225/225 - 1s - loss: 0.3698 - accuracy: 0.8515 - val_loss: 0.3353 - val_accuracy: 0.8575 - 778ms/epoch - 3ms/step
# Epoch 156/200
# 225/225 - 1s - loss: 0.3772 - accuracy: 0.8514 - val_loss: 0.3356 - val_accuracy: 0.8625 - 736ms/epoch - 3ms/step
# Epoch 157/200
# 225/225 - 1s - loss: 0.3774 - accuracy: 0.8478 - val_loss: 0.3345 - val_accuracy: 0.8600 - 1s/epoch - 5ms/step
# Epoch 158/200
# 225/225 - 1s - loss: 0.3765 - accuracy: 0.8479 - val_loss: 0.3357 - val_accuracy: 0.8625 - 958ms/epoch - 4ms/step
# Epoch 159/200
# 225/225 - 1s - loss: 0.3733 - accuracy: 0.8476 - val_loss: 0.3356 - val_accuracy: 0.8625 - 710ms/epoch - 3ms/step
# Epoch 160/200
# 225/225 - 1s - loss: 0.3738 - accuracy: 0.8497 - val_loss: 0.3331 - val_accuracy: 0.8637 - 725ms/epoch - 3ms/step
# Epoch 161/200
# 225/225 - 1s - loss: 0.3702 - accuracy: 0.8515 - val_loss: 0.3372 - val_accuracy: 0.8575 - 752ms/epoch - 3ms/step
# Epoch 162/200
# 225/225 - 1s - loss: 0.3717 - accuracy: 0.8501 - val_loss: 0.3336 - val_accuracy: 0.8612 - 682ms/epoch - 3ms/step
# Epoch 163/200
# 225/225 - 1s - loss: 0.3708 - accuracy: 0.8535 - val_loss: 0.3330 - val_accuracy: 0.8637 - 694ms/epoch - 3ms/step
# Epoch 164/200
# 225/225 - 1s - loss: 0.3720 - accuracy: 0.8487 - val_loss: 0.3343 - val_accuracy: 0.8612 - 729ms/epoch - 3ms/step
# Epoch 165/200
# 225/225 - 1s - loss: 0.3723 - accuracy: 0.8511 - val_loss: 0.3338 - val_accuracy: 0.8612 - 642ms/epoch - 3ms/step
# Epoch 166/200
# 225/225 - 1s - loss: 0.3738 - accuracy: 0.8485 - val_loss: 0.3357 - val_accuracy: 0.8600 - 756ms/epoch - 3ms/step
# Epoch 167/200
# 225/225 - 1s - loss: 0.3730 - accuracy: 0.8528 - val_loss: 0.3323 - val_accuracy: 0.8637 - 656ms/epoch - 3ms/step
# Epoch 168/200
# 225/225 - 1s - loss: 0.3756 - accuracy: 0.8489 - val_loss: 0.3334 - val_accuracy: 0.8625 - 748ms/epoch - 3ms/step
# Epoch 169/200
# 225/225 - 1s - loss: 0.3745 - accuracy: 0.8475 - val_loss: 0.3362 - val_accuracy: 0.8600 - 767ms/epoch - 3ms/step
# Epoch 170/200
# 225/225 - 1s - loss: 0.3748 - accuracy: 0.8504 - val_loss: 0.3350 - val_accuracy: 0.8612 - 675ms/epoch - 3ms/step
# Epoch 171/200
# 225/225 - 1s - loss: 0.3709 - accuracy: 0.8490 - val_loss: 0.3366 - val_accuracy: 0.8550 - 854ms/epoch - 4ms/step
# Epoch 172/200
# 225/225 - 1s - loss: 0.3743 - accuracy: 0.8524 - val_loss: 0.3369 - val_accuracy: 0.8600 - 623ms/epoch - 3ms/step
# Epoch 173/200
# 225/225 - 1s - loss: 0.3753 - accuracy: 0.8481 - val_loss: 0.3327 - val_accuracy: 0.8650 - 690ms/epoch - 3ms/step
# Epoch 174/200
# 225/225 - 1s - loss: 0.3716 - accuracy: 0.8517 - val_loss: 0.3331 - val_accuracy: 0.8600 - 988ms/epoch - 4ms/step
# Epoch 175/200
# 225/225 - 1s - loss: 0.3727 - accuracy: 0.8492 - val_loss: 0.3345 - val_accuracy: 0.8575 - 1s/epoch - 7ms/step
# Epoch 176/200
# 225/225 - 1s - loss: 0.3724 - accuracy: 0.8496 - val_loss: 0.3335 - val_accuracy: 0.8612 - 829ms/epoch - 4ms/step
# Epoch 177/200
# 225/225 - 1s - loss: 0.3734 - accuracy: 0.8517 - val_loss: 0.3349 - val_accuracy: 0.8625 - 647ms/epoch - 3ms/step
# Epoch 178/200
# 225/225 - 1s - loss: 0.3714 - accuracy: 0.8493 - val_loss: 0.3347 - val_accuracy: 0.8612 - 686ms/epoch - 3ms/step
# Epoch 179/200
# 225/225 - 1s - loss: 0.3724 - accuracy: 0.8479 - val_loss: 0.3335 - val_accuracy: 0.8625 - 640ms/epoch - 3ms/step
# Epoch 180/200
# 225/225 - 1s - loss: 0.3738 - accuracy: 0.8553 - val_loss: 0.3384 - val_accuracy: 0.8550 - 811ms/epoch - 4ms/step
# Epoch 181/200
# 225/225 - 1s - loss: 0.3734 - accuracy: 0.8493 - val_loss: 0.3331 - val_accuracy: 0.8600 - 841ms/epoch - 4ms/step
# Epoch 182/200
# 225/225 - 1s - loss: 0.3728 - accuracy: 0.8514 - val_loss: 0.3333 - val_accuracy: 0.8612 - 866ms/epoch - 4ms/step
# Epoch 183/200
# 225/225 - 1s - loss: 0.3740 - accuracy: 0.8506 - val_loss: 0.3340 - val_accuracy: 0.8637 - 1s/epoch - 5ms/step
# Epoch 184/200
# 225/225 - 1s - loss: 0.3734 - accuracy: 0.8510 - val_loss: 0.3320 - val_accuracy: 0.8650 - 1s/epoch - 5ms/step
# Epoch 185/200
# 225/225 - 1s - loss: 0.3685 - accuracy: 0.8515 - val_loss: 0.3371 - val_accuracy: 0.8612 - 650ms/epoch - 3ms/step
# Epoch 186/200
# 225/225 - 1s - loss: 0.3692 - accuracy: 0.8499 - val_loss: 0.3348 - val_accuracy: 0.8625 - 655ms/epoch - 3ms/step
# Epoch 187/200
# 225/225 - 1s - loss: 0.3718 - accuracy: 0.8515 - val_loss: 0.3358 - val_accuracy: 0.8625 - 606ms/epoch - 3ms/step
# Epoch 188/200
# 225/225 - 1s - loss: 0.3721 - accuracy: 0.8494 - val_loss: 0.3340 - val_accuracy: 0.8662 - 696ms/epoch - 3ms/step
# Epoch 189/200
# 225/225 - 1s - loss: 0.3704 - accuracy: 0.8511 - val_loss: 0.3349 - val_accuracy: 0.8625 - 746ms/epoch - 3ms/step
# Epoch 190/200
# 225/225 - 1s - loss: 0.3721 - accuracy: 0.8526 - val_loss: 0.3383 - val_accuracy: 0.8625 - 702ms/epoch - 3ms/step
# Epoch 191/200
# 225/225 - 1s - loss: 0.3741 - accuracy: 0.8504 - val_loss: 0.3380 - val_accuracy: 0.8600 - 646ms/epoch - 3ms/step
# Epoch 192/200
# 225/225 - 1s - loss: 0.3751 - accuracy: 0.8492 - val_loss: 0.3363 - val_accuracy: 0.8650 - 672ms/epoch - 3ms/step
# Epoch 193/200
# 225/225 - 1s - loss: 0.3690 - accuracy: 0.8476 - val_loss: 0.3354 - val_accuracy: 0.8612 - 908ms/epoch - 4ms/step
# Epoch 194/200
# 225/225 - 1s - loss: 0.3731 - accuracy: 0.8529 - val_loss: 0.3342 - val_accuracy: 0.8625 - 916ms/epoch - 4ms/step
# Epoch 195/200
# 225/225 - 1s - loss: 0.3793 - accuracy: 0.8510 - val_loss: 0.3358 - val_accuracy: 0.8625 - 1s/epoch - 6ms/step
# Epoch 196/200
# 225/225 - 1s - loss: 0.3721 - accuracy: 0.8465 - val_loss: 0.3360 - val_accuracy: 0.8612 - 900ms/epoch - 4ms/step
# Epoch 197/200
# 225/225 - 1s - loss: 0.3735 - accuracy: 0.8503 - val_loss: 0.3355 - val_accuracy: 0.8612 - 1s/epoch - 4ms/step
# Epoch 198/200
# 225/225 - 1s - loss: 0.3689 - accuracy: 0.8543 - val_loss: 0.3359 - val_accuracy: 0.8650 - 927ms/epoch - 4ms/step
# Epoch 199/200
# 225/225 - 1s - loss: 0.3698 - accuracy: 0.8524 - val_loss: 0.3382 - val_accuracy: 0.8637 - 674ms/epoch - 3ms/step
# Epoch 200/200
# 225/225 - 1s - loss: 0.3732 - accuracy: 0.8535 - val_loss: 0.3359 - val_accuracy: 0.8587 - 1s/epoch - 5ms/step

# %%
y_pred = classifier.predict(X_test)
print(y_pred[:5])
# Out:
# 63/63 [==============================] - 0s 3ms/step
# [[0.291146  ]
#  [0.35604283]
#  [0.2525747 ]
#  [0.05964612]
#  [0.09835186]]

# %%
#Let us use confusion matrix with cutoff value as 0.5
y_pred = (y_pred > 0.5).astype(int)
print(y_pred[:5])
# Out:
# [[0]
#  [0]
#  [0]
#  [0]
#  [0]]

# %%
#Making the Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1537   58]
#  [ 214  191]]

# %%
#Accuracy of our NN
print(((cm[0][0] + cm[1][1])* 100) / len(y_test), '% of data was classified correctly')
# Out:
# 86.4 % of data was classified correctly
